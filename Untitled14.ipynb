# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('data1.csv')
data.head()
# Out:
#    columna_x  columna_y columna_categorica
# 0          1          2                  A
# 1          2          4                  B
# 2          3          6                  A
# 3          4          8                  C
# 4          5         10                  B

# %%
data.describe()
# Out:
#        columna_x  columna_y
# count   10.00000  10.000000
# mean     5.50000  11.000000
# std      3.02765   6.055301
# min      1.00000   2.000000
# 25%      3.25000   6.500000
# 50%      5.50000  11.000000
# 75%      7.75000  15.500000
# max     10.00000  20.000000

# %%
print(data)
# Out:
#    columna_x  columna_y columna_categorica
# 0          1          2                  A
# 1          2          4                  B
# 2          3          6                  A
# 3          4          8                  C
# 4          5         10                  B
# 5          6         12                  A
# 6          7         14                  C
# 7          8         16                  B
# 8          9         18                  C
# 9         10         20                  A

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   columna_x           10 non-null     int64
#  1   columna_y           10 non-null     int64
#  2   columna_categorica  10 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
if 'columna' in data.columns:
 data['columna'] = data['columna'].astype(float)
else:
 print("Column 'columna' not found in the DataFrame.")
# Out:
# Column 'columna' not found in the DataFrame.

# %%
plt.hist(data['columna_x'], bins=5,
color='skyblue', edgecolor='black')
# Out:
# (array([2., 2., 2., 2., 2.]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.scatter(data['columna_x'],
data['columna_y'], color='green', s=100,
edgecolors='black', alpha=0.75)

# %%
import matplotlib.pyplot as plt
data['columna_categorica'].value_counts().plot(kind='bar',color='orange', edgecolor='black')
# Out:
# <Axes: xlabel='columna_categorica'>

# %%
df=pd.read_csv('datos salud..csv')
df.head()
# Out:
#    Edad Genero  Colesterol  Presion_Arterial Hipertension
# 0    69      M         235               112           Sí
# 1    32      F         294               179           No
# 2    89      M         291               146           Sí
# 3    78      M         158               148           No
# 4    38      M         243                91           No

# %%
df.describe()
# Out:
#               Edad   Colesterol  Presion_Arterial
# count  5000.000000  5000.000000        5000.00000
# mean     53.299000   223.149400         138.80940
# std      20.646851    42.928266          34.79742
# min      18.000000   150.000000          80.00000
# 25%      36.000000   186.000000         108.00000
# 50%      53.000000   223.000000         138.00000
# 75%      71.000000   260.000000         169.00000
# max      89.000000   299.000000         199.00000

# %%
valores_nulos=df.isnull().sum()
print(valores_nulos)
# Out:
# Edad                0
# Genero              0
# Colesterol          0
# Presion_Arterial    0
# Hipertension        0
# dtype: int64

# %%
df_cleaned = df[(df['Presion_Arterial'] >= 90) & (df['Presion_Arterial'] <= 180)]
print(df_cleaned)
# Out:
#       Edad Genero  Colesterol  Presion_Arterial Hipertension
# 0       69      M         235               112           Sí
# 1       32      F         294               179           No
# 2       89      M         291               146           Sí
# 3       78      M         158               148           No
# 4       38      M         243                91           No
# ...    ...    ...         ...               ...          ...
# 4991    89      M         155                96           No
# 4992    73      M         216               168           No
# 4996    43      F         246               110           Sí
# 4997    58      F         229               148           No
# 4999    40      M         287               119           No
#
# [3757 rows x 5 columns]

# %%
df.to_csv('datos_salud.csv', index=False)
df_cleaned.to_csv('datos_salud_limpios.csv', index=False)

# %%
plt.scatter(df_cleaned['Edad'], df_cleaned['Colesterol'], c='blue', alpha=0.5)

# %%
df_cleaned['Hipertension'].value_counts().plot(kind='bar', color='green',
edgecolor='black')
# Out:
# <Axes: xlabel='Hipertension'>

# %% [markdown]
# laboratorio escenario 1

# %%
df_financiero=pd.read_csv('datos_financieros.csv')
print(df_financiero)
# Out:
#       Edad Genero Historial_Crediticio  Salario_Anual    Deuda
# 0       56      M              Regular        61037.0  22443.0
# 1       69      F                Bueno        31805.0  39725.0
# 2       46      F                Bueno        63147.0  49212.0
# 3       32      M                 Malo        94280.0  18595.0
# 4       60      M              Regular        66053.0   9740.0
# ...    ...    ...                  ...            ...      ...
# 4995    24      M              Regular       116777.0  27655.0
# 4996    66      F                 Malo       101909.0  29143.0
# 4997    26      F              Regular       107409.0  15698.0
# 4998    53      F                 Malo        57664.0      NaN
# 4999    36      F                 Malo        21293.0   9102.0
#
# [5000 rows x 5 columns]

# %%
df_financiero.head()
# Out:
#    Edad Genero Historial_Crediticio  Salario_Anual    Deuda
# 0    56      M              Regular        61037.0  22443.0
# 1    69      F                Bueno        31805.0  39725.0
# 2    46      F                Bueno        63147.0  49212.0
# 3    32      M                 Malo        94280.0  18595.0
# 4    60      M              Regular        66053.0   9740.0

# %%
print("Resumen de los datos:")
print(df_financiero.describe())

#df_financiero.fillna({"Salario_Anual":np.median}, inplace=True)
#df_financiero.fillna({"Deuda":np.median}, inplace=True)
df_financiero['Salario_Anual'].fillna(df_financiero['Salario_Anual'].median(), inplace=True)
df_financiero['Deuda'].fillna(df_financiero['Deuda'].median(), inplace=True)
# Out:
# Resumen de los datos:
#               Edad  Salario_Anual         Deuda
# count  5000.000000    4800.000000   4850.000000
# mean     43.584600   69131.827917  25137.928454
# std      14.919094   29221.920701  14478.122739
# min      18.000000   20005.000000     18.000000
# 25%      31.000000   43049.500000  12817.500000
# 50%      43.000000   69636.500000  24841.500000
# 75%      56.000000   94543.000000  37690.250000
# max      69.000000  119987.000000  49999.000000
# <ipython-input-31-903b48821352>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_financiero['Salario_Anual'].fillna(df_financiero['Salario_Anual'].median(), inplace=True)
# <ipython-input-31-903b48821352>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_financiero['Deuda'].fillna(df_financiero['Deuda'].median(), inplace=True)

# %%
print("\nVerificación de valores nulos después de la limpieza:")
print(df_financiero.isnull().sum())

df_financiero.to_csv('datos_financieros_limpios.csv', index=False)
# Out:
# Verificación de valores nulos después de la limpieza:
# Edad                    0
# Genero                  0
# Historial_Crediticio    0
# Salario_Anual           0
# Deuda                   0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_financiero['Edad'], df_financiero['Deuda'], c='green', alpha=0.5)
plt.title('Relación entre Edad y Deuda', fontsize=15)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Deuda', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Segundo Escenario

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df_salud = pd.read_csv('datos_salud glu.csv')

print("Resumen de los datos:")
print(df_salud.describe())
print("\nVerificación de valores nulos:")
print(df_salud.isnull().sum())
# Out:
# Resumen de los datos:
#               Edad      Glucosa          IMC
# count  5000.000000  4800.000000  4850.000000
# mean     53.299000   133.858125    26.708239
# std      20.646851    37.196858     4.808900
# min      18.000000    70.000000    18.502603
# 25%      36.000000   101.000000    22.515387
# 50%      53.000000   134.000000    26.613110
# 75%      71.000000   165.000000    30.979322
# max      89.000000   199.000000    34.998760
#
# Verificación de valores nulos:
# Edad                         0
# Genero                       0
# Glucosa                    200
# IMC                        150
# Antecedentes_Familiares      0
# dtype: int64

# %%
df_salud['Glucosa'].fillna(df_salud['Glucosa'].median(), inplace=True)
df_salud['IMC'].fillna(df_salud['IMC'].median(), inplace=True)
print("\nVerificación de valores nulos después de la limpieza:")
print(df_salud.isnull().sum())
# Out:
# Verificación de valores nulos después de la limpieza:
# Edad                       0
# Genero                     0
# Glucosa                    0
# IMC                        0
# Antecedentes_Familiares    0
# dtype: int64
# <ipython-input-35-5d5b5c63133e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_salud['Glucosa'].fillna(df_salud['Glucosa'].median(), inplace=True)
# <ipython-input-35-5d5b5c63133e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_salud['IMC'].fillna(df_salud['IMC'].median(), inplace=True)

# %%
df_salud.to_csv('datos_salud glu_limpios.csv', index=False)
df_salud.to_csv('datos_salud_limpios.csv', index=False)
plt.figure(figsize=(10, 6))
plt.scatter(df_salud['Edad'], df_salud['Glucosa'], c='blue', alpha=0.5)
plt.title('Relación entre Edad y Niveles de Glucosa', fontsize=15)
plt.xlabel('Edad', fontsize=12)
plt.ylabel('Niveles de Glucosa', fontsize=12)
plt.grid(True)

z = np.polyfit(df_salud['Edad'], df_salud['Glucosa'], 1)
p = np.poly1d(z)
plt.plot(df_salud['Edad'], p(df_salud['Edad']), color='red', label='Tendencia')
plt.legend()
plt.show()
plt.figure(figsize=(8, 6))
df_salud['Antecedentes_Familiares'].value_counts().plot(kind='bar', color='green', edgecolor='black')

plt.title('Distribución de Antecedentes Familiares de Diabetes', fontsize=15)
plt.xlabel('Antecedentes Familiares', fontsize=12)
plt.ylabel('Cantidad de Pacientes', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
